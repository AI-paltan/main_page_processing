# %%
import pandas as pd
import numpy as np
import IPython
from IPython.display import display

# %%
from process_core import mainPageProcess
# Out:
# /home/jayesh/anaconda3/envs/crm_syd/lib/python3.9/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
from CPL_mapping import CPLMapping

# %%
fileid = "599060e9-8b46-46ec-87b9-c79cde8a82b7"

# %%
mp = mainPageProcess()

# %%
cbs_dict,cpl_dict,ccf_dict,meta_dict,final_notes_dict,ref_notes_list, notes_region_meta_data,cropped_table_dict = mp.process_main_pages(fileid=fileid)
# Out:
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/utils.py:54: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_idx, item in row.iteritems():
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/utils.py:54: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_idx, item in row.iteritems():
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/utils.py:54: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_idx, item in row.iteritems():
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:174: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_idx, item in row.iteritems():
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:293: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.iloc[:,col] = df.iloc[:,col].apply(clean_number).apply(pd.to_numeric , errors='coerce')
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:174: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_idx, item in row.iteritems():
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:293: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.iloc[:,col] = df.iloc[:,col].apply(clean_number).apply(pd.to_numeric , errors='coerce')
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:174: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_idx, item in row.iteritems():
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:293: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.iloc[:,col] = df.iloc[:,col].apply(clean_number).apply(pd.to_numeric , errors='coerce')
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:174: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_idx, item in row.iteritems():
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:293: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.iloc[:,col] = df.iloc[:,col].apply(clean_number).apply(pd.to_numeric , errors='coerce')
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:174: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_idx, item in row.iteritems():
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:293: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.iloc[:,col] = df.iloc[:,col].apply(clean_number).apply(pd.to_numeric , errors='coerce')
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:174: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_idx, item in row.iteritems():
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:293: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.iloc[:,col] = df.iloc[:,col].apply(clean_number).apply(pd.to_numeric , errors='coerce')
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:174: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_idx, item in row.iteritems():
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:293: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.iloc[:,col] = df.iloc[:,col].apply(clean_number).apply(pd.to_numeric , errors='coerce')
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:174: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_idx, item in row.iteritems():
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:293: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.iloc[:,col] = df.iloc[:,col].apply(clean_number).apply(pd.to_numeric , errors='coerce')
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:466: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_header , line_row in fin_df.filter(like="line_item", axis=1).iteritems():
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:174: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_idx, item in row.iteritems():
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:293: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.iloc[:,col] = df.iloc[:,col].apply(clean_number).apply(pd.to_numeric , errors='coerce')
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:174: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_idx, item in row.iteritems():
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:293: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.iloc[:,col] = df.iloc[:,col].apply(clean_number).apply(pd.to_numeric , errors='coerce')
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:174: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_idx, item in row.iteritems():
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:293: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.iloc[:,col] = df.iloc[:,col].apply(clean_number).apply(pd.to_numeric , errors='coerce')
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:466: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_header , line_row in fin_df.filter(like="line_item", axis=1).iteritems():
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:174: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_idx, item in row.iteritems():
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:293: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.iloc[:,col] = df.iloc[:,col].apply(clean_number).apply(pd.to_numeric , errors='coerce')
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:174: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_idx, item in row.iteritems():
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:293: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.iloc[:,col] = df.iloc[:,col].apply(clean_number).apply(pd.to_numeric , errors='coerce')
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:174: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_idx, item in row.iteritems():
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:293: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.iloc[:,col] = df.iloc[:,col].apply(clean_number).apply(pd.to_numeric , errors='coerce')
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:174: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_idx, item in row.iteritems():
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:293: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.iloc[:,col] = df.iloc[:,col].apply(clean_number).apply(pd.to_numeric , errors='coerce')
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:174: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_idx, item in row.iteritems():
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:293: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.iloc[:,col] = df.iloc[:,col].apply(clean_number).apply(pd.to_numeric , errors='coerce')
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:174: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_idx, item in row.iteritems():
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:293: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.iloc[:,col] = df.iloc[:,col].apply(clean_number).apply(pd.to_numeric , errors='coerce')
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:174: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_idx, item in row.iteritems():
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:293: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.iloc[:,col] = df.iloc[:,col].apply(clean_number).apply(pd.to_numeric , errors='coerce')
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:174: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_idx, item in row.iteritems():
# /home/jayesh/mgs_ai/crm_syd_1/main_page_processing_service/note_standardise_utils.py:293: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.iloc[:,col] = df.iloc[:,col].apply(clean_number).apply(pd.to_numeric , errors='coerce')

# %%
cpl_dict[6].columns = cpl_dict[6].columns.map(str)

# %%
obj_cpl_mapping = CPLMapping(cpl_df=cpl_dict[6],notes_ref_dict=mp.notes_ref_dict,notes_region_meta_data=mp.notes_region_meta_data,standardised_cropped_dict=mp.standardised_cropped_dict,standard_note_meta_dict=mp.standard_note_meta_dict,transformed_standardised_cropped_dict=mp.transformed_standardised_cropped_dict)

# %%
obj_cpl_mapping.trigger_job()

# %%
obj_cpl_mapping.bs_bucket_dict
# Out:
# {'smr_sales': {'main_page_row_indices': [0],
#   'main_page_year_total': [229785.0, 214911.0],
#   'main_page_raw_note': ['4.1'],
#   'main_page_particular_text_list': ['Revenue from contracts with customers'],
#   'main_page_value_list': [[229785.0], [214911.0]],
#   'notes_table_df':    raw_note_no note_no subnote_no  \
#   0          4.1       4          1
#   1          4.1       4          1
#   2          4.1       4          1
#   3          4.1       4          1
#   4          4.1       4          1
#   5          4.1       4          1
#   6          4.1       4          1
#   7          4.1       4          1
#   8          4.1       4          1
#   9          4.1       4          1
#   10         4.1       4          1
#   11         4.1       4          1
#   12         4.1       4          1
#   13         4.1       4          1
#   14         4.1       4          1
#   15         4.1       4          1
#   16         4.1       4          1
#   17         4.1       4          1
#   18         4.1       4          1
#   19         4.1       4          1
#
#                                               line_item  year     value
#   0                    $000 Type of goods Type of goods  2020       0.0
#   1                    $000 Type of goods Sale of goods  2020  214911.0
#   2   $000 Type of goods Total revenue from contract...  2020  214911.0
#   3      $000 Geographical markets Geographical markets  2020       0.0
#   4                     $000 Geographical markets Japan  2020  190814.0
#   5                 $000 Geographical markets Australia  2020   24097.0
#   6   $000 Geographical markets Total revenue from c...  2020  214911.0
#   7   $000 Timing of revenue recognition Timing of r...  2020       0.0
#   8   $000 Timing of revenue recognition Goods trans...  2020  214911.0
#   9   $000 Timing of revenue recognition Total reven...  2020  214911.0
#   10                   $000 Type of goods Type of goods  2019       0.0
#   11                   $000 Type of goods Sale of goods  2019  229785.0
#   12  $000 Type of goods Total revenue from contract...  2019  229785.0
#   13     $000 Geographical markets Geographical markets  2019       0.0
#   14                    $000 Geographical markets Japan  2019  197789.0
#   15                $000 Geographical markets Australia  2019   31996.0
#   16  $000 Geographical markets Total revenue from c...  2019  229785.0
#   17  $000 Timing of revenue recognition Timing of r...  2019       0.0
#   18  $000 Timing of revenue recognition Goods trans...  2019  229785.0
#   19  $000 Timing of revenue recognition Total reven...  2019  229785.0  },
#  'cost_of_sales': {'main_page_row_indices': [3],
#   'main_page_year_total': [-249283.0, -227382.0],
#   'main_page_raw_note': [],
#   'main_page_particular_text_list': ['Cost of sales'],
#   'main_page_value_list': [[-249283.0], [-227382.0]],
#   'notes_table_df': Empty DataFrame
#   Columns: [raw_note_no, note_no, subnote_no, line_item, year, value]
#   Index: []},
#  'sga_total_sga_expenses': {'main_page_row_indices': [],
#   'main_page_year_total': [0, 0],
#   'main_page_raw_note': [],
#   'main_page_particular_text_list': [],
#   'main_page_value_list': [[], []],
#   'notes_table_df': Empty DataFrame
#   Columns: [raw_note_no, note_no, subnote_no, line_item, year, value]
#   Index: []},
#  'smr_rent': {'main_page_row_indices': [],
#   'main_page_year_total': [0, 0],
#   'main_page_raw_note': [],
#   'main_page_particular_text_list': [],
#   'main_page_value_list': [[], []],
#   'notes_table_df': Empty DataFrame
#   Columns: [raw_note_no, note_no, subnote_no, line_item, year, value]
#   Index: []},
#  'smr_others_opr_income': {'main_page_row_indices': [],
#   'main_page_year_total': [0, 0],
#   'main_page_raw_note': [],
#   'main_page_particular_text_list': [],
#   'main_page_value_list': [[], []],
#   'notes_table_df': Empty DataFrame
#   Columns: [raw_note_no, note_no, subnote_no, line_item, year, value]
#   Index: []},
#  'smr_interest_income': {'main_page_row_indices': [5, 8],
#   'main_page_year_total': [10314.0, 13691.0],
#   'main_page_raw_note': ['4.3', '4.4'],
#   'main_page_particular_text_list': ['Other income', 'Finance income'],
#   'main_page_value_list': [[10144.0, 170.0], [13631.0, 60.0]],
#   'notes_table_df':   raw_note_no note_no subnote_no            line_item  year value
#   0         4.4       4          4  $000  Bank interest  2020    60
#   1         4.4       4          4  $000  Bank interest  2019   170},
#  'smr_interest_expense': {'main_page_row_indices': [9],
#   'main_page_year_total': [-618.0, -539.0],
#   'main_page_raw_note': ['4.5'],
#   'main_page_particular_text_list': ['Finance costs'],
#   'main_page_value_list': [[-618.0], [-539.0]],
#   'notes_table_df':   raw_note_no note_no subnote_no                line_item  year value
#   0         4.5       4          5  $000  Interest expenses  2020  -203
#   1         4.5       4          5  $000  Interest expenses  2019  -303},
#  'noie_oi_or_exp': {'main_page_row_indices': [],
#   'main_page_year_total': [0, 0],
#   'main_page_raw_note': [],
#   'main_page_particular_text_list': [],
#   'main_page_value_list': [[], []],
#   'notes_table_df': Empty DataFrame
#   Columns: [raw_note_no, note_no, subnote_no, line_item, year, value]
#   Index: []},
#  'oie_oi': {'main_page_row_indices': [],
#   'main_page_year_total': [0, 0],
#   'main_page_raw_note': [],
#   'main_page_particular_text_list': [],
#   'main_page_value_list': [[], []],
#   'notes_table_df': Empty DataFrame
#   Columns: [raw_note_no, note_no, subnote_no, line_item, year, value]
#   Index: []},
#  'smr_taxes': {'main_page_row_indices': [],
#   'main_page_year_total': [0, 0],
#   'main_page_raw_note': [],
#   'main_page_particular_text_list': [],
#   'main_page_value_list': [[], []],
#   'notes_table_df': Empty DataFrame
#   Columns: [raw_note_no, note_no, subnote_no, line_item, year, value]
#   Index: []},
#  'smr_minority_interest': {'main_page_row_indices': [],
#   'main_page_year_total': [0, 0],
#   'main_page_raw_note': [],
#   'main_page_particular_text_list': [],
#   'main_page_value_list': [[], []],
#   'notes_table_df': Empty DataFrame
#   Columns: [raw_note_no, note_no, subnote_no, line_item, year, value]
#   Index: []},
#  'smr_extraordinary_gain_loss': {'main_page_row_indices': [],
#   'main_page_year_total': [0, 0],
#   'main_page_raw_note': [],
#   'main_page_particular_text_list': [],
#   'main_page_value_list': [[], []],
#   'notes_table_df': Empty DataFrame
#   Columns: [raw_note_no, note_no, subnote_no, line_item, year, value]
#   Index: []}}

# %%
cpl_dict[6]
# Out:
#                                           Particulars Notes     2020      2019
# 0               Revenue from contracts with customers   4.1   214911  229785.0
# 1                                       Other revenue   4.2      775     780.0
# 2                                             Revenue   NaN   215686  230565.0
# 3                                       Cost of sales   NaN  -227382 -249283.0
# 4                                          Gross loss   NaN   -11696  -18718.0
# 5                                        Other income   4.3    13631   10144.0
# 6   Share of gain/(loss) of joint venture, net of tax    11     1586   -7587.0
# 7                             Administrative expenses   NaN    -5557   -4069.0
# 8                                      Finance income   4.4       60     170.0
# 9                                       Finance costs   4.5     -539    -618.0
# 10                                    Impairment loss    12   -25567       0.0
# 11                             Loss before income tax   NaN   -28082  -20678.0
# 12                                 Income tax benefit     5     8217    3944.0
# 13                                  Loss for the year   NaN   -19865  -16734.0

# %%
mp.final_notes_dict
# Out:
# {'6': {'': ['Cash and cash equivalents', 'Cash and cash equivalents at 31 December']}, '7': {'': ['Trade and other receivables']}, '8': {'': ['Inventories']}, '9': {'': ['Financial assets', 'Financial assets']}, '20': {'': ['Income tax receivable from related parties']}, '10': {'': ['Other current assets', 'Other non-current assets']}, '11': {'': ['Investment in joint ventures', 'Share of gain/(loss) of joint venture, net of tax']}, '12': {'': ['Property, plant and equipment', 'Impairment loss']}, '13': {'': ['Right-of-use assets', 'Lease liabilities', 'Lease liabilities']}, '5': {'': ['Deferred tax assets', 'Deferred tax liabilities', 'Income tax benefit']}, '16': {'': ['Borrowings']}, '17': {'': ['Provisions', 'Provisions']}, '15': {'': ['Financial liabilities']}, '18': {'': ['Contributed equity']}, '19': {'': ['Reserves']}, '4': {'1': ['Revenue from contracts with customers'], '2': ['Other revenue'], '3': ['Other income'], '4': ['Finance income'], '5': ['Finance costs']}}

# %%
mp.notes_ref_dict
# Out:
# {'cbs': [{'particular': 'Cash and cash equivalents',
#    'raw_note_no': '6',
#    'processed_raw_note': ['6'],
#    'main_note_number': ['6'],
#    'subnote_number': ['']},
#   {'particular': 'Trade and other receivables',
#    'raw_note_no': '7',
#    'processed_raw_note': ['7'],
#    'main_note_number': ['7'],
#    'subnote_number': ['']},
#   {'particular': 'Inventories',
#    'raw_note_no': '8',
#    'processed_raw_note': ['8'],
#    'main_note_number': ['8'],
#    'subnote_number': ['']},
#   {'particular': 'Financial assets',
#    'raw_note_no': '9',
#    'processed_raw_note': ['9'],
#    'main_note_number': ['9'],
#    'subnote_number': ['']},
#   {'particular': 'Income tax receivable from related parties',
#    'raw_note_no': '20',
#    'processed_raw_note': ['20'],
#    'main_note_number': ['20'],
#    'subnote_number': ['']},
#   {'particular': 'Other current assets',
#    'raw_note_no': '10',
#    'processed_raw_note': ['10'],
#    'main_note_number': ['10'],
#    'subnote_number': ['']},
#   {'particular': 'Investment in joint ventures',
#    'raw_note_no': '11',
#    'processed_raw_note': ['11'],
#    'main_note_number': ['11'],
#    'subnote_number': ['']},
#   {'particular': 'Property, plant and equipment',
#    'raw_note_no': '12',
#    'processed_raw_note': ['12'],
#    'main_note_number': ['12'],
#    'subnote_number': ['']},
#   {'particular': 'Right-of-use assets',
#    'raw_note_no': '13',
#    'processed_raw_note': ['13'],
#    'main_note_number': ['13'],
#    'subnote_number': ['']},
#   {'particular': 'Financial assets',
#    'raw_note_no': '9',
#    'processed_raw_note': ['9'],
#    'main_note_number': ['9'],
#    'subnote_number': ['']},
#   {'particular': 'Deferred tax assets',
#    'raw_note_no': '5',
#    'processed_raw_note': ['5'],
#    'main_note_number': ['5'],
#    'subnote_number': ['']},
#   {'particular': 'Other non-current assets',
#    'raw_note_no': '10',
#    'processed_raw_note': ['10'],
#    'main_note_number': ['10'],
#    'subnote_number': ['']},
#   {'particular': 'Borrowings',
#    'raw_note_no': '16',
#    'processed_raw_note': ['16'],
#    'main_note_number': ['16'],
#    'subnote_number': ['']},
#   {'particular': 'Provisions',
#    'raw_note_no': '17',
#    'processed_raw_note': ['17'],
#    'main_note_number': ['17'],
#    'subnote_number': ['']},
#   {'particular': 'Financial liabilities',
#    'raw_note_no': '15',
#    'processed_raw_note': ['15'],
#    'main_note_number': ['15'],
#    'subnote_number': ['']},
#   {'particular': 'Lease liabilities',
#    'raw_note_no': '13',
#    'processed_raw_note': ['13'],
#    'main_note_number': ['13'],
#    'subnote_number': ['']},
#   {'particular': 'Provisions',
#    'raw_note_no': '17',
#    'processed_raw_note': ['17'],
#    'main_note_number': ['17'],
#    'subnote_number': ['']},
#   {'particular': 'Lease liabilities',
#    'raw_note_no': '13',
#    'processed_raw_note': ['13'],
#    'main_note_number': ['13'],
#    'subnote_number': ['']},
#   {'particular': 'Deferred tax liabilities',
#    'raw_note_no': '5',
#    'processed_raw_note': ['5'],
#    'main_note_number': ['5'],
#    'subnote_number': ['']},
#   {'particular': 'Contributed equity',
#    'raw_note_no': '18',
#    'processed_raw_note': ['18'],
#    'main_note_number': ['18'],
#    'subnote_number': ['']},
#   {'particular': 'Reserves',
#    'raw_note_no': '19',
#    'processed_raw_note': ['19'],
#    'main_note_number': ['19'],
#    'subnote_number': ['']}],
#  'cpl': [{'particular': 'Revenue from contracts with customers',
#    'raw_note_no': '4.1',
#    'processed_raw_note': ['4.1'],
#    'main_note_number': ['4'],
#    'subnote_number': ['1']},
#   {'particular': 'Other revenue',
#    'raw_note_no': '4.2',
#    'processed_raw_note': ['4.2'],
#    'main_note_number': ['4'],
#    'subnote_number': ['2']},
#   {'particular': 'Other income',
#    'raw_note_no': '4.3',
#    'processed_raw_note': ['4.3'],
#    'main_note_number': ['4'],
#    'subnote_number': ['3']},
#   {'particular': 'Share of gain/(loss) of joint venture, net of tax',
#    'raw_note_no': '11',
#    'processed_raw_note': ['11'],
#    'main_note_number': ['11'],
#    'subnote_number': ['']},
#   {'particular': 'Finance income',
#    'raw_note_no': '4.4',
#    'processed_raw_note': ['4.4'],
#    'main_note_number': ['4'],
#    'subnote_number': ['4']},
#   {'particular': 'Finance costs',
#    'raw_note_no': '4.5',
#    'processed_raw_note': ['4.5'],
#    'main_note_number': ['4'],
#    'subnote_number': ['5']},
#   {'particular': 'Impairment loss',
#    'raw_note_no': '12',
#    'processed_raw_note': ['12'],
#    'main_note_number': ['12'],
#    'subnote_number': ['']},
#   {'particular': 'Income tax benefit',
#    'raw_note_no': '5',
#    'processed_raw_note': ['5'],
#    'main_note_number': ['5'],
#    'subnote_number': ['']}],
#  'ccf': [{'particular': 'Cash and cash equivalents at 31 December',
#    'raw_note_no': '6',
#    'processed_raw_note': ['6'],
#    'main_note_number': ['6'],
#    'subnote_number': ['']}]}
